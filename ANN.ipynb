# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint

from sklearn.model_selection import train_test_split
np.random.seed(500)

# %%
df = pd.read_csv(r'C:\Users\Bhavesh\Downloads\pima1.csv')

# %%
df.head()
# Out:
#    pregnancy  plasma_glucose  distolic_bp  skin_thick  insuline   BMI  \
# 0          6             148           72          35         0  33.6
# 1          1              85           66          29         0  26.6
# 2          8             183           64           0         0  23.3
# 3          1              89           66          23        94  28.1
# 4          0             137           40          35       168  43.1
#
#    pedigree_fn  age         Diabetes
# 0        0.627   50  tested_positive
# 1        0.351   31  tested_negative
# 2        0.672   32  tested_positive
# 3        0.167   21  tested_negative
# 4        2.288   33  tested_positive

# %%
df.Diabetes = np.where(df['Diabetes'] == 'tested_negative',0,1)
df.head()
# Out:
#    pregnancy  plasma_glucose  distolic_bp  skin_thick  insuline   BMI  \
# 0          6             148           72          35         0  33.6
# 1          1              85           66          29         0  26.6
# 2          8             183           64           0         0  23.3
# 3          1              89           66          23        94  28.1
# 4          0             137           40          35       168  43.1
#
#    pedigree_fn  age  Diabetes
# 0        0.627   50         1
# 1        0.351   31         0
# 2        0.672   32         1
# 3        0.167   21         0
# 4        2.288   33         1

# %%
features = list(df.columns.values)
features.remove('Diabetes')

# %%
X = df[features]
y = df.Diabetes

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
